# %% [markdown]
# #Object Detection
#
# Run it in Google Colab or go to https://colab.research.google.com/drive/1GbRKSJao-8jO7P4AaF2Bb9nbQGGfvEWC?usp=sharing

# %% [markdown]
# ##### Copyright 2018 The TensorFlow Hub Authors.
#
# Licensed under the Apache License, Version 2.0 (the "License");

# %% [markdown]
# # Object Detection

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://www.tensorflow.org/hub/tutorials/object_detection"><img src="https://www.tensorflow.org/images/tf_logo_32px.png" />View on TensorFlow.org</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/tensorflow/hub/blob/master/examples/colab/object_detection.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/tensorflow/hub/blob/master/examples/colab/object_detection.ipynb"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View on GitHub</a>
#   </td>
#   <td>
#     <a href="https://storage.googleapis.com/tensorflow_docs/hub/examples/colab/object_detection.ipynb"><img src="https://www.tensorflow.org/images/download_logo_32px.png" />Download notebook</a>
#   </td>
#   <td>
#     <a href="https://tfhub.dev/s?q=google%2Ffaster_rcnn%2Fopenimages_v4%2Finception_resnet_v2%2F1%20OR%20google%2Ffaster_rcnn%2Fopenimages_v4%2Finception_resnet_v2%2F1"><img src="https://www.tensorflow.org/images/hub_logo_32px.png" />See TF Hub models</a>
#   </td>
# </table>

# %% [markdown]
# This Colab demonstrates use of a TF-Hub module trained to perform object detection.

# %% [markdown]
# ## Setup

# %%
#@title Imports and function definitions

# For running inference on the TF-Hub module.
import tensorflow as tf

import tensorflow_hub as hub

# For downloading the image.
import matplotlib.pyplot as plt
import tempfile
from six.moves.urllib.request import urlopen
from six import BytesIO

# For drawing onto the image.
import numpy as np
from PIL import Image
from PIL import ImageColor
from PIL import ImageDraw
from PIL import ImageFont
from PIL import ImageOps

# For measuring the inference time.
import time

import collections
import pandas as pd

# Print Tensorflow version
print(tf.__version__)

# Check available GPU devices.
print("The following GPU devices are available: %s" % tf.test.gpu_device_name())
# Out:
# 2.5.0
# The following GPU devices are available:

# %%
from google.colab import drive
drive.mount('/drive')
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %%
def display_image(image):
  fig = plt.figure(figsize=(20, 15))
  plt.grid(False)
  plt.imshow(image)


def download_and_resize_image(url, new_width=256, new_height=256,
                              display=False):
  _, filename = tempfile.mkstemp(suffix=".jpg")
  response = urlopen(url)
  image_data = response.read()
  image_data = BytesIO(image_data)
  pil_image = Image.open(image_data)
  pil_image = ImageOps.fit(pil_image, (new_width, new_height), Image.ANTIALIAS)
  pil_image_rgb = pil_image.convert("RGB")
  pil_image_rgb.save(filename, format="JPEG", quality=90)
  print("Image downloaded to %s." % filename)
  if display:
    display_image(pil_image)
  return filename


def draw_bounding_box_on_image(image,
                               ymin,
                               xmin,
                               ymax,
                               xmax,
                               color,
                               font,
                               thickness=4,
                               display_str_list=()):
  """Adds a bounding box to an image."""
  draw = ImageDraw.Draw(image)
  im_width, im_height = image.size
  (left, right, top, bottom) = (xmin * im_width, xmax * im_width,
                                ymin * im_height, ymax * im_height)
  draw.line([(left, top), (left, bottom), (right, bottom), (right, top),
             (left, top)],
            width=thickness,
            fill=color)

  # If the total height of the display strings added to the top of the bounding
  # box exceeds the top of the image, stack the strings below the bounding box
  # instead of above.
  display_str_heights = [font.getsize(ds)[1] for ds in display_str_list]
  # Each display_str has a top and bottom margin of 0.05x.
  total_display_str_height = (1 + 2 * 0.05) * sum(display_str_heights)

  if top > total_display_str_height:
    text_bottom = top
  else:
    text_bottom = top + total_display_str_height
  # Reverse list and print from bottom to top.
  for display_str in display_str_list[::-1]:
    text_width, text_height = font.getsize(display_str)
    margin = np.ceil(0.05 * text_height)
    draw.rectangle([(left, text_bottom - text_height - 2 * margin),
                    (left + text_width, text_bottom)],
                   fill=color)
    draw.text((left + margin, text_bottom - text_height - margin),
              display_str,
              fill="black",
              font=font)
    text_bottom -= text_height - 2 * margin


def draw_boxes(image, boxes, class_names, scores, max_boxes=10, min_score=0.1):
  """Overlay labeled boxes on an image with formatted scores and label names."""
  colors = list(ImageColor.colormap.values())

  try:
    font = ImageFont.truetype("/usr/share/fonts/truetype/liberation/LiberationSansNarrow-Regular.ttf",
                              25)
  except IOError:
    print("Font not found, using default font.")
    font = ImageFont.load_default()

  for i in range(min(boxes.shape[0], max_boxes)):
    if scores[i] >= min_score:
      ymin, xmin, ymax, xmax = tuple(boxes[i])
      display_str = "{}: {}%".format(class_names[i].decode("ascii"),
                                     int(100 * scores[i]))
      color = colors[hash(class_names[i]) % len(colors)]
      image_pil = Image.fromarray(np.uint8(image)).convert("RGB")
      draw_bounding_box_on_image(
          image_pil,
          ymin,
          xmin,
          ymax,
          xmax,
          color,
          font,
          display_str_list=[display_str])
      np.copyto(image, np.array(image_pil))
  return image

# %% [markdown]
# Pick an object detection module and apply on the downloaded image. Modules:
# * **FasterRCNN+InceptionResNet V2**: high accuracy,
# * **ssd+mobilenet V2**: small and fast.

# %%
module_handle = "https://tfhub.dev/google/faster_rcnn/openimages_v4/inception_resnet_v2/1" #@param ["https://tfhub.dev/google/openimages_v4/ssd/mobilenet_v2/1", "https://tfhub.dev/google/faster_rcnn/openimages_v4/inception_resnet_v2/1"]

detector = hub.load(module_handle).signatures['default']
# Out:
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore

# %%
def load_img(path):
  img = tf.io.read_file(path)
  img = tf.image.decode_jpeg(img, channels=3)
  return img

# %%
def run_detector(detector, path):
  img = load_img(path)

  converted_img  = tf.image.convert_image_dtype(img, tf.float32)[tf.newaxis, ...]
  start_time = time.time()
  result = detector(converted_img)
  end_time = time.time()

  result = {key:value.numpy() for key,value in result.items()}

  # image_with_boxes = draw_boxes(
  #     img.numpy(), result["detection_boxes"],
  #     result["detection_class_entities"], result["detection_scores"])

  # display_image(image_with_boxes)

  counting_raw = dict(collections.Counter(result["detection_class_entities"]))
  counting = {str(key).split("'")[1]: value for key, value in counting_raw.items()}
  labels = [k for k in counting]
  return labels

# %%
def detect_img(image_url):
  start_time = time.time()
  image_path = download_and_resize_image(image_url, 640, 480)
  labels = run_detector(detector, image_path)
  end_time = time.time()
  inference_time = end_time-start_time
  return labels, inference_time

# %%
images_file = "/drive/My Drive/Hermes/Object detection/input-images-od-posts - images.csv"
images_posts = pd.read_csv(images_file)
images_posts.head()
# Out:
#                                             post_url  ...                                          media_url
# 0  https://www.linkedin.com/feed/update/urn:li:ac...  ...  ['https://media-exp3.licdn.com/dms/image/C4D1F...
# 1  https://www.linkedin.com/feed/update/urn:li:ac...  ...  https://media-exp3.licdn.com/dms/image/C4E22AQ...
# 2  https://www.linkedin.com/feed/update/urn:li:ac...  ...  ['https://media-exp3.licdn.com/dms/image/C4E22...
# 3  https://www.linkedin.com/feed/update/urn:li:ac...  ...  https://media-exp3.licdn.com/dms/image/C4D22AQ...
# 4  https://www.linkedin.com/feed/update/urn:li:ac...  ...  https://media-exp3.licdn.com/dms/image/C4E22AQ...
#
# [5 rows x 4 columns]

# %%
object_detection = pd.DataFrame(columns=["post_url","media_url","author","media_type","inferenceTime","object"])
# object_detection = pd.read_csv("data/output-object-detection.csv")[["post_url","media_url","author","media_type","inferenceTime","object"]]
# start = max(len(object_detection)-1,0)
start = 0
start
# Out:
# 0

# %%
from urllib.error import HTTPError

for i, row in images_posts.iterrows():
    if i >= start and i<i+100:
      print(i, row['media_type'])
      if row['media_type'] == 'Single image':
        try:
          labels, inference_time = detect_img(row['media_url'])
          print(i,labels[:5])
          for k in range(5):
            image = pd.DataFrame([[row['post_url'],row['media_url'],row['author'],row['media_type'],inference_time, labels[k]]], columns=["post_url","media_url","author","media_type","inferenceTime","object"])
            object_detection = object_detection.append(image)
            object_detection.to_csv("/drive/My Drive/Hermes/Object detection/output-object-detection.csv")
        except:
          image = pd.DataFrame([[row['post_url'],row['media_url'],row['author'],row['media_type'],'', '']], columns=["post_url","media_url","author","media_type","inferenceTime","object"])
          object_detection = object_detection.append(image)
          object_detection.to_csv("/drive/My Drive/Hermes/Object detection/output-object-detection.csv")
      elif row['media_type'] in ['Carousel', 'Multiple images']:
        for img in row['media_url'].replace('[','').replace(']','').replace("'",'').split(','):
          if type(img) == 'None':
            continue
          try:
            labels, inference_time = detect_img(str(img))
            print(i,labels[:5])
            for k in range(5):
              image = pd.DataFrame([[row['post_url'],img,row['author'],row['media_type'],inference_time, labels[k]]], columns=["post_url","media_url","author","media_type","inferenceTime","object"])
              object_detection = object_detection.append(image)
              object_detection.to_csv("/drive/My Drive/Hermes/Object detection/output-object-detection.csv")
          except HTTPError as err:
            image = pd.DataFrame([[row['post_url'],img,row['author'],row['media_type'],'', '403 Forbidden']], columns=["post_url","media_url","author","media_type","inferenceTime","object"])
            object_detection = object_detection.append(image)
            object_detection.to_csv("/drive/My Drive/Hermes/Object detection/output-object-detection.csv")
          except:
            image = pd.DataFrame([[row['post_url'],img,row['author'],row['media_type'],'', '']], columns=["post_url","media_url","author","media_type","inferenceTime","object"])
            object_detection = object_detection.append(image)
            object_detection.to_csv("/drive/My Drive/Hermes/Object detection/output-object-detection.csv")
# Out:
# 0 Carousel
# Image downloaded to /tmp/tmp2lha6zig.jpg.
# 0 ['Clothing', 'Woman', 'Poster', 'Human face', 'Person']
# 1 Single image
# Image downloaded to /tmp/tmpmblo_drv.jpg.
# 1 ['Computer keyboard', 'Laptop', 'Office supplies', 'Land vehicle', 'Mobile phone']
# 2 Multiple images
# Image downloaded to /tmp/tmpkvch6pjb.jpg.
# 2 ['Man', 'Human face', 'Woman', 'Person', 'Clothing']
# Image downloaded to /tmp/tmpdw3tx5t0.jpg.
# 2 ['Person', 'Man', 'Clothing', 'Table', 'Human face']
# Image downloaded to /tmp/tmpwge6qm7x.jpg.
# 2 ['Man', 'Woman', 'Human face', 'Jeans', 'Suit']
# 3 Single image
# Image downloaded to /tmp/tmp7adtrf7z.jpg.
# 3 ['Tablet computer', 'Poster', 'Mobile phone', 'Computer monitor', 'Laptop']
# 4 Single image
# Image downloaded to /tmp/tmpa8d9hphx.jpg.
# 4 ['Poster', 'Clothing', 'Whiteboard', 'Flag', 'Envelope']
# 5 Single image
# Image downloaded to /tmp/tmpc5c5fnp2.jpg.
# 5 ['Human face', 'Poster', 'Clothing', 'Woman', 'Person']
# 6 Single image
# ...
